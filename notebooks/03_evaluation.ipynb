# %% [markdown]
# # 03 - Evaluation & Visualization

# %% [markdown]
# > Scaffold notebook — fill with data and code.

# %%
import matplotlib.pyplot as plt

team = teams[0]  # ilk takım örnek
plt.hist(points[team], bins=30)
plt.title(f"{team} points distribution (Monte Carlo)")
plt.xlabel("Points")
plt.ylabel("Frequency")
plt.show()

# %%
avg_df = pd.DataFrame({
    "team": teams,
    "avg_points": [np.mean(points[t]) for t in teams]
}).sort_values("avg_points", ascending=False)

avg_df

# %% [markdown]
# ## Diagnostic plots

# %%
# TODO

# %% [markdown]
# ## Export figures

# %%
# TODO
